# %% [markdown]
# [View in Colaboratory](https://colab.research.google.com/github/sizips0418/financedata/blob/master/FinanceDataReader%EC%82%AC%EC%9A%A9%EB%B2%95.ipynb)

# %%
import pandas as pd
import numpy as n

# %%
# !pip install -U finance-datareader
# Out:
# Collecting finance-datareader
#   Downloading https://files.pythonhosted.org/packages/40/2f/4fa9f40be5112f36fa315867394598dacbf2d9392935f65d83ccdee4d10c/finance_datareader-0.4.0-py3-none-any.whl
# Collecting requests-file (from finance-datareader)
#   Downloading https://files.pythonhosted.org/packages/23/9c/6e63c23c39e53d3df41c77a3d05a49a42c4e1383a6d2a5e3233161b89dbf/requests_file-1.4.3-py2.py3-none-any.whl
# Requirement not upgraded as not directly required: requests>=2.3.0 in /usr/local/lib/python3.6/dist-packages (from finance-datareader) (2.18.4)
# Collecting lxml (from finance-datareader)
#   Downloading https://files.pythonhosted.org/packages/a7/b9/ccf46cea0f698b40bca2a9c1a44039c336fe1988b82de4f7353be7a8396a/lxml-4.2.1-cp36-cp36m-manylinux1_x86_64.whl (5.6MB)
#     100% |████████████████████████████████| 5.7MB 4.2MB/s
# Requirement not upgraded as not directly required: pandas>=0.19.2 in /usr/local/lib/python3.6/dist-packages (from finance-datareader) (0.22.0)
# Requirement not upgraded as not directly required: six in /usr/local/lib/python3.6/dist-packages (from requests-file->finance-datareader) (1.11.0)
# Requirement not upgraded as not directly required: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests>=2.3.0->finance-datareader) (2018.4.16)
# Requirement not upgraded as not directly required: urllib3<1.23,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests>=2.3.0->finance-datareader) (1.22)
# Requirement not upgraded as not directly required: chardet<3.1.0,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests>=2.3.0->finance-datareader) (3.0.4)
# Requirement not upgraded as not directly required: idna<2.7,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests>=2.3.0->finance-datareader) (2.6)
# Requirement not upgraded as not directly required: python-dateutil>=2 in /usr/local/lib/python3.6/dist-packages (from pandas>=0.19.2->finance-datareader) (2.5.3)
# Requirement not upgraded as not directly required: numpy>=1.9.0 in /usr/local/lib/python3.6/dist-packages (from pandas>=0.19.2->finance-datareader) (1.14.3)
# Requirement not upgraded as not directly required: pytz>=2011k in /usr/local/lib/python3.6/dist-packages (from pandas>=0.19.2->finance-datareader) (2018.4)
# Installing collected packages: requests-file, lxml, finance-datareader
# Successfully installed finance-datareader-0.4.0 lxml-4.2.1 requests-file-1.4.3

# %%
import FinanceDataReader as fdr

# %%
df_krx = fdr.StockListing('KRX')
df_krx.head()
# Out:
#    Symbol     Name                     Sector  \
# 0  001460      BYC                   봉제의복 제조업
# 1  079160   CJ CGV  영화, 비디오물, 방송프로그램 제작 및 배급업
# 2  005830   DB손해보험                        보험업
# 3  139130  DGB금융지주                     기타 금융업
# 4  069730    DSR제강                  1차 철강 제조업
#
#                             Industry
# 0   메리야스,란제리 제조,도매/건축공사/부동산 임대,분양,공급
# 1                        영화상영,영화관 운영
# 2          자동차보험,화재보험,해상보험,특종보험,장기보험
# 3                               지주회사
# 4  와이어로프,각종 경강선,철선제품,PC강선,아연도 강연선 제조

# %%
len(df_krx)
# Out:
# 2194

# %%
df_spx = fdr.StockListing('S&P500')
df_spx.head()
# Out:
#   Symbol                 Name                  Sector  \
# 0    MMM           3M Company             Industrials
# 1    ABT  Abbott Laboratories             Health Care
# 2   ABBV          AbbVie Inc.             Health Care
# 3    ACN        Accenture plc  Information Technology
# 4   ATVI  Activision Blizzard  Information Technology
#
#                          Industry
# 0        Industrial Conglomerates
# 1           Health Care Equipment
# 2                 Pharmaceuticals
# 3  IT Consulting & Other Services
# 4     Home Entertainment Software

# %%
# 신라젠, 2018년
df = fdr.DataReader('215600', '2018')
df.head()
# Out:
#              Close    Open    High    Low     Volume  Change
# Date
# 2018-01-01   93500   93500   93500  93500        0.0  0.0000
# 2018-01-02  102500   95900  104000  93300  6760000.0  0.0963
# 2018-01-03  103000  102600  104900  99500  4720000.0  0.0049
# 2018-01-04   92200  102600  104000  92200  6390000.0 -0.1049
# 2018-01-05  100000   85800  101200  85700  8250000.0  0.0846

# %%
#셀트리온, 2017 ~ 현재
df = fdr.DataReader('068270', '2017')
df.head()
# Out:
#              Close    Open    High     Low    Volume  Change
# Date
# 2017-01-01  107400  107400  107400  107400     450.0  0.0200
# 2017-01-02  106078  105490  106176  104510  440440.0 -0.0123
# 2017-01-03  104510  105588  106078  104020  388000.0 -0.0148
# 2017-01-04  104020  104902  104902  103039  355520.0 -0.0047
# 2017-01-05  104314  104314  105392  103725  314340.0  0.0028

# %%
# 애플(AAPL), 2018-01-01 ~ 2018-03-30
df = fdr.DataReader('AAPL', '2018-01-01', '2018-03-30')
df.tail()
# Out:
#              Close    Open    High     Low      Volume  Change
# Date
# 2018-03-23  164.94  168.39  169.92  164.94  41030000.0 -0.0232
# 2018-03-26  172.77  168.07  173.10  166.44  37540000.0  0.0475
# 2018-03-27  168.34  173.68  175.15  166.92  40920000.0 -0.0256
# 2018-03-28  166.48  167.25  170.02  165.19  41670000.0 -0.0110
# 2018-03-29  167.78  167.81  171.75  166.90  38400000.0  0.0078

# %%
# 애플(AAPL), 2017년
df = fdr.DataReader('AAPL', '2017')
df['Close'].plot()

# %%
# 아마존(AMZN), 2010~현재
df = fdr.DataReader('AMZN', '2010')
df['Close'].plot()

# %%
# KS11 (KOSPI 지수), 2015년~현재
df = fdr.DataReader('KS11', '2015')
df['Close'].plot()

# %%
# 다우지수, 2015년~현재

df = fdr.DataReader('DJI', '2015')
df['Close'].plot()

# %%
# 원달러 환율, 1995년~현재
df = fdr.DataReader('USD/KRW', '1995')
df['Close'].plot()

# %%
# 비트코인 원화 가격 (빗썸), 2016년~현재
df = fdr.DataReader('BTC/KRW', '2016')
df['Close'].plot()

# %%
# CME 비트코인 선물 가격
df = fdr.DataReader('BTC', '2017')
df['Close'].plot()
